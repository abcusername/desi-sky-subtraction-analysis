# %%
import sys
print("Python version:", sys.version)
# Out:
# Python version: 3.11.15 | packaged by Anaconda, Inc. | (main, Mar 11 2026, 17:12:15) [MSC v.1942 64 bit (AMD64)]

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

print("numpy OK")
print("matplotlib OK")
print("astropy OK")
# Out:
# numpy OK
# matplotlib OK
# astropy OK

# %%
try:
    from desispec.io import read_spectra
    print("desispec OK")
except Exception as e:
    print("desispec import failed:")
    print(e)
# Out:
# desispec import failed:
# No module named 'desispec'

# %%
try:
    import fitsio
    print("fitsio OK")
except Exception as e:
    print("fitsio import failed:")
    print(e)
# Out:
# fitsio import failed:
# No module named 'fitsio'
