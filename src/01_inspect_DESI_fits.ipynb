# %%
import os

print("Current working directory:")
print(os.getcwd())

print("\nFiles in this folder:")
for f in os.listdir():
    print(f)
# Out:
# Current working directory:
# C:\Users\30126\Desktop\吴鑫星兰州大学\项目\李所  顾一舟\DESI_sky_project
#
# Files in this folder:
# .ipynb_checkpoints
# 00_environment_check.ipynb.ipynb
# 01_inspect_DESI_fits.ipynb.ipynb
# 05_Spectra.ipynb
